# %% [markdown]
# # Model Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_models = pd.read_csv('Model_Results.csv',index_col=0)

# %%
df_models
# Out:
#      Len_load  building  square_feet  meter  file_name  Len_agg-clean  \
# 0       24787         7       121074      1    7_1.pkl           1037
# 1       24460        13        99380      1   13_1.pkl           1037
# 2       24789        14        86250      1   14_1.pkl           1037
# 3       24789        15        83957      1   15_1.pkl           1037
# 4       23727        28        52957      1   28_1.pkl            993
# ..        ...       ...          ...    ...        ...            ...
# 130     26301       188        23549      0  188_0.pkl           1096
# 131     26301       189         7481      0  189_0.pkl           1096
# 132     26301       190       137040      0  190_0.pkl           1096
# 133     26301       190       137040      1  190_1.pkl           1096
# 134     26301       190       137040      3  190_3.pkl           1096
#
#      Len_blank  Model_1_Type                   Model_1_Description  \
# ...

# %%
sns.lineplot(data=df_models,x='square_feet',y='Model_3_y_pred_RMSE_pct_Range')
# Out:
# <AxesSubplot:xlabel='square_feet', ylabel='Model_3_y_pred_RMSE_pct_Range'>
